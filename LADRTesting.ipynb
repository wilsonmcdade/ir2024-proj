# %%
# !pip install python-terrier faiss-cpu
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_dr.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 25.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.2/335.2 kB 35.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import pyterrier as pt
if not pt.started():
  pt.init()
from pyterrier_dr import NumpyIndex, FlexIndex
from pyterrier_dr.flex import LadrPreemptive, IndexingMode
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8

# %%
dataset = pt.datasets.get_dataset('vaswani')

flex_index = FlexIndex('./index', indexing_mode=IndexingMode.overwrite)
flex_index.index(dataset.get_corpus())

scorer = flex_index.scorer
# Out:
# indexing: 0dvec [00:00, ?dvec/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e90007abd653> in <cell line: 4>()
#       2
#       3 flex_index = FlexIndex('./index', indexing_mode=IndexingMode.overwrite)
# ----> 4 flex_index.index(dataset.get_corpus())
#       5
#       6 scorer = flex_index.scorer
#
# /usr/local/lib/python3.10/dist-packages/pyterrier_dr/flex/core.py in index(self, inp)
#      74         with open(path/'vecs.f4', 'wb') as fout, Lookup.builder(path/'docnos.npids') as docnos:
#      75             for d in inp:
# ---> 76                 vec = d['doc_vec']
#      77                 if vec_size is None:
#      78                     vec_size = vec.shape[0]
#
# TypeError: string indices must be integers

# %%
ladr = LadrPreemptive(flex_index, flex_index.corpus_graph(16), scorer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9eae6094ab89> in <cell line: 1>()
# ----> 1 ladr = LadrPreemptive(FlexIndex(index), index.corpus_graph(16))
#
# /usr/local/lib/python3.10/dist-packages/pyterrier_dr/flex/core.py in __init__(self, index_path, num_results, sim_fn, indexing_mode, verbose)
#      26 class FlexIndex(pt.Indexer):
#      27     def __init__(self, index_path, num_results=1000, sim_fn=SimFn.dot, indexing_mode=IndexingMode.create, verbose=True):
# ---> 28         self.index_path = Path(index_path)
#      29         self.num_results = num_results
#      30         self.sim_fn = SimFn(sim_fn)
#
# /usr/lib/python3.10/pathlib.py in __new__(cls, *args, **kwargs)
#     958         if cls is Path:
#     959             cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 960         self = cls._from_parts(args)
# ...

# %%
pt.Experiment(
    [ladr],
    dataset.get_topics(),
    dataset.get_qrels(),
    [R@100],
    named=['LADR']
)
